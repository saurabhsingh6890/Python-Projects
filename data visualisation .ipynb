# %% [markdown]
# ##### code:

# %%
#importing the libraries:
import pandas as pd
import numpy as np
from sklearn.datasets import make_classification
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # partA

# %%
#creating the dataset:
x, y = make_classification(n_samples=10000,
                           n_features=12,
                           n_informative=4,
                           n_redundant=8,
                           n_clusters_per_class=2,
                           n_classes=3,
                           random_state=123)

# %%
df = pd.DataFrame(x, columns = ['F1','F2','F3','F4','F5','F6','F7','F8','F9','F10','F11','F12'])

# %% [markdown]
#  ### Dataset Exploration

# %%
df.head()
# Out:
#          F1        F2        F3        F4        F5        F6        F7  \
# 0  0.295416 -0.144006 -1.615861  1.034985  3.413970  2.185575 -1.094784
# 1  0.571642  0.427204  0.606245 -1.582681 -1.924233 -0.952325  0.567578
# 2 -0.956609 -0.500754 -0.581051 -0.816802 -1.256933 -0.402253  0.842367
# 3 -1.488293 -4.091132 -3.302764 -3.182493  0.962326  3.392692 -1.785556
# 4  0.252358 -0.613697  1.939337 -0.042551 -1.326050 -0.828616 -0.790994
#
#          F8        F9       F10       F11       F12
# 0  1.050899  1.511180  1.102392  2.391804 -0.884762
# 1  0.570707  0.629061 -0.917640 -1.430082  1.126460
# 2 -0.716074 -0.562580 -2.325733 -1.415574  2.147172
# 3  0.133440  4.779634 -3.456940 -1.374901  4.310302
# 4 -0.792874 -0.259919  1.853556 -0.628895 -1.758465

# %%
df.head(10)
# Out:
#          F1        F2        F3        F4        F5        F6        F7  \
# 0  0.295416 -0.144006 -1.615861  1.034985  3.413970  2.185575 -1.094784
# 1  0.571642  0.427204  0.606245 -1.582681 -1.924233 -0.952325  0.567578
# 2 -0.956609 -0.500754 -0.581051 -0.816802 -1.256933 -0.402253  0.842367
# 3 -1.488293 -4.091132 -3.302764 -3.182493  0.962326  3.392692 -1.785556
# 4  0.252358 -0.613697  1.939337 -0.042551 -1.326050 -0.828616 -0.790994
# 5 -0.802926 -0.790304 -0.761111 -0.461553 -0.236883  0.299536  0.169553
# 6  1.224844  0.473242  0.794020 -1.401483 -1.039667 -0.409428 -0.193881
# 7  0.607198  0.535477  0.813166 -1.506965 -2.093319 -1.147797  0.633419
# 8  3.193832  4.809881  2.631732  0.911025 -0.895734 -2.688277  1.566914
# 9 -1.902583 -1.660547 -0.945833 -0.475593 -0.955913  0.081873  0.445225
#
#          F8        F9       F10       F11       F12
# 0  1.050899  1.511180  1.102392  2.391804 -0.884762
# 1  0.570707  0.629061 -0.917640 -1.430082  1.126460
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.describe()
# Out:
#                  F1            F2            F3            F4            F5  \
# count  10000.000000  10000.000000  10000.000000  10000.000000  10000.000000
# mean      -0.002044     -0.446674      0.008606     -0.318826     -0.034990
# std        1.425953      2.302888      1.464225      1.490050      2.191369
# min       -5.672041     -8.466880     -4.488822     -5.408371     -7.549882
# 25%       -0.852196     -1.856460     -1.075758     -1.292236     -1.549544
# 50%        0.120122     -0.422831     -0.120674     -0.597984     -0.226316
# 75%        0.900389      0.732728      1.029033      0.606114      1.174665
# max        5.482878     11.613698      5.736618      5.828816      9.525639
#
#                  F6            F7            F8            F9           F10  \
# count  10000.000000  10000.000000  10000.000000  10000.000000  10000.000000
# mean       0.241279     -0.359469     -0.003193      0.543930      0.095278
# ...

# %%
df.shape
# Out:
# (10000, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 12 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   F1      10000 non-null  float64
#  1   F2      10000 non-null  float64
#  2   F3      10000 non-null  float64
#  3   F4      10000 non-null  float64
#  4   F5      10000 non-null  float64
#  5   F6      10000 non-null  float64
#  6   F7      10000 non-null  float64
#  7   F8      10000 non-null  float64
#  8   F9      10000 non-null  float64
#  9   F10     10000 non-null  float64
#  10  F11     10000 non-null  float64
#  11  F12     10000 non-null  float64
# dtypes: float64(12)
# memory usage: 937.6 KB

# %% [markdown]
# ## creatingh the required classes in first four features F1,F2,F3,F4

# %%
df['F1'].describe()
# Out:
# count    10000.000000
# mean        -0.002044
# std          1.425953
# min         -5.672041
# 25%         -0.852196
# 50%          0.120122
# 75%          0.900389
# max          5.482878
# Name: F1, dtype: float64

# %%
def f1change(x):
    if x >=0:
        return (True)
    else:
        return (False)

# %%
f1change(43)
# Out:
# True

# %%
f1change(-2)
# Out:
# False

# %%
df['F1'] = df['F1'].apply(f1change)

# %%
df['F1']
# Out:
# 0        True
# 1        True
# 2       False
# 3       False
# 4        True
#         ...
# 9995    False
# 9996     True
# 9997    False
# 9998    False
# 9999    False
# Name: F1, Length: 10000, dtype: bool

# %%
df['F5']
# Out:
# 0       3.413970
# 1      -1.924233
# 2      -1.256933
# 3       0.962326
# 4      -1.326050
#           ...
# 9995    1.695294
# 9996    2.115637
# 9997    1.164458
# 9998   -1.623922
# 9999    1.023271
# Name: F5, Length: 10000, dtype: float64

# %%
## trying with np.where
np.where(df['F5']>=0, True,False)
# Out:
# array([ True, False, False, ...,  True, False,  True])

# %%
df.F2.describe()
# Out:
# count    10000.000000
# mean        -0.446674
# std          2.302888
# min         -8.466880
# 25%         -1.856460
# 50%         -0.422831
# 75%          0.732728
# max         11.613698
# Name: F2, dtype: float64

# %%
df['F2']
# Out:
# 0      -0.144006
# 1       0.427204
# 2      -0.500754
# 3      -4.091132
# 4      -0.613697
#           ...
# 9995   -4.417446
# 9996    0.298252
# 9997   -1.847522
# 9998   -2.488734
# 9999   -1.366426
# Name: F2, Length: 10000, dtype: float64

# %%
df['F2'] = np.where(df['F2']>=0.4, 'Type 1','Type 2')

# %%
df['F3'].describe()
# Out:
# count    10000.000000
# mean         0.008606
# std          1.464225
# min         -4.488822
# 25%         -1.075758
# 50%         -0.120674
# 75%          1.029033
# max          5.736618
# Name: F3, dtype: float64

# %%
df['F3']
# Out:
# 0      -1.615861
# 1       0.606245
# 2      -0.581051
# 3      -3.302764
# 4       1.939337
#           ...
# 9995   -1.169052
# 9996    0.199881
# 9997   -0.642895
# 9998   -0.263459
# 9999   -1.161453
# Name: F3, Length: 10000, dtype: float64

# %%
def f2(y):
    if y <= 0:
        return ('A')
    elif y < 1:
        return ('B')
    else:
        return ('C')

# %%
df['F3'].apply(f2)
# Out:
# 0       A
# 1       B
# 2       A
# 3       A
# 4       C
#        ..
# 9995    A
# 9996    B
# 9997    A
# 9998    A
# 9999    A
# Name: F3, Length: 10000, dtype: object

# %%
df['F3']=df['F3'].apply(f2)
df['F3']
# Out:
# 0       A
# 1       B
# 2       A
# 3       A
# 4       C
#        ..
# 9995    A
# 9996    B
# 9997    A
# 9998    A
# 9999    A
# Name: F3, Length: 10000, dtype: object

# %%
df['F4'].describe()
# Out:
# count    10000.000000
# mean        -0.318826
# std          1.490050
# min         -5.408371
# 25%         -1.292236
# 50%         -0.597984
# 75%          0.606114
# max          5.828816
# Name: F4, dtype: float64

# %%
df['F4']
# Out:
# 0       1.034985
# 1      -1.582681
# 2      -0.816802
# 3      -3.182493
# 4      -0.042551
#           ...
# 9995   -0.914846
# 9996    1.807518
# 9997   -0.266705
# 9998   -1.074000
# 9999    1.332360
# Name: F4, Length: 10000, dtype: float64

# %%
df['F4']=np.where(df['F4']<-0.318826, "Low", (np.where(df['F4']<0.606114, "Medium","High")))

# %%
df['F4']
# Out:
# 0         High
# 1          Low
# 2          Low
# 3          Low
# 4       Medium
#          ...
# 9995       Low
# 9996      High
# 9997    Medium
# 9998       Low
# 9999      High
# Name: F4, Length: 10000, dtype: object

# %%
print("Value counts:")
print("------------------")
print("F1:")
print(df.F1.value_counts())
print("-------------------")
print("F2:")
print(df.F2.value_counts())
print("-------------------")
print("F3:")
print(df.F3.value_counts())
print("-------------------")
print("F4:")
print(df.F4.value_counts())
print("-------------------")
# Out:
# Value counts:
# ------------------
# F1:
# True     5337
# False    4663
# Name: F1, dtype: int64
# -------------------
# F2:
# Type 2    6879
# Type 1    3121
# Name: F2, dtype: int64
# -------------------
# F3:
# A    5302
# C    2560
# B    2138
# Name: F3, dtype: int64
# -------------------
# F4:
# Low       5790
# High      2500
# Medium    1710
# Name: F4, dtype: int64
# -------------------

# %%
print("unique class:")
print("------------------")
print("F1:")
print(df.F1.nunique())
print("-------------------")
print("F2:")
print(df.F2.nunique())
print("-------------------")
print("F3:")
print(df.F3.nunique())
print("-------------------")
print("F4:")
print(df.F4.nunique())
print("-------------------")
# Out:
# unique class:
# ------------------
# F1:
# 2
# -------------------
# F2:
# 2
# -------------------
# F3:
# 3
# -------------------
# F4:
# 3
# -------------------

# %%
print("unique class name:")
print("------------------")
print("F1:")
print(df.F1.unique())
print("-------------------")
print("F2:")
print(df.F2.unique())
print("-------------------")
print("F3:")
print(df.F3.unique())
print("-------------------")
print("F4:")
print(df.F4.unique())
print("-------------------")
# Out:
# unique class name:
# ------------------
# F1:
# [ True False]
# -------------------
# F2:
# ['Type 2' 'Type 1']
# -------------------
# F3:
# ['A' 'B' 'C']
# -------------------
# F4:
# ['High' 'Low' 'Medium']
# -------------------

# %% [markdown]
# ## 22 feb 2023

# %% [markdown]
# ## Part B:
# Exploring different kind of plots and findout hidden patterns in dataset.

# %% [markdown]
# #### Displot
# - displot()
# - The displot represents the univariate distribution of data i.e data distribution of a variable against the density distribution.
# - It accept the data variables as an argument and rturns the plot with density distribution.

# %%
sns.distplot(df["F5"], color = 'red')     #1 numerical feature
plt.title("Dist plot")
plt.xlabel("Distribution of F5")
plt.show()

# %% [markdown]
# ### Scatter plot:
# - used for bivariate analysis.
# - plota betweeen two numerical features to check the distribution and spread of data pointa among both of the features.

# %%
plt.scatter(x='F6', y='F7',data=df,color='pink')
plt.title("scatter plot")
plt.xlabel("F6")
plt.ylabel("F7")
plt.show()

# %% [markdown]
# ## Jointplot:
# - a jointplot comprises three piots.
# - one plot displays a bivariate graph which shows how the dpendent variable(y) varies the independent variable(x).
# - Another plot is placed horizontally at the top of the bivariate graph and it shows the distribution of the independent variable(x)

# %%
sns.jointplot(x='F6', y='F7',data=df,kind='scatter',color="black")  #kind` must be one of ['scatter', 'hist', 'hex', 'kde', 'reg', 'resid'], but he was passed.`

plt.title("joint plot")
plt.show()

# %% [markdown]
# ## pairplot:
# - pairplot()
# - used to multivariate analysis.
# - to plot multiple pairwise bivariate distribution in a dataset.

# %%
sns.pairplot(df)
plt.title("Pair plot")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\numpy\lib\histograms.py in _unsigned_subtract(a, b)
#     350     try:
# --> 351         dt = signed_to_unsigned[dt.type]
#     352     except KeyError:
#
# KeyError: <class 'numpy.bool_'>
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6500\188776201.py in <module>
# ----> 1 sns.pairplot(df)
#       2 plt.title("Pair plot")
#       3 plt.show()
#
# ~\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ...

# %% [markdown]
# ## Rugplot
# - a rug plot is a simple plot to explore distribution of a continuos variable.

# %%
sns.rugplot(data=df, x="F8")
plt.show()

# %%
plt.figure(figsize=(5,3))
sns.rugplot(data=df, x="F8")
plt.show()

# %%
plt.figure(figsize=(8,8))
plt.subplot(2,3,1)   ##row,column,index
plt.subplot(2,3,2)
plt.subplot(2,3,3)
plt.subplot(2,3,4)
plt.subplot(2,3,5)
plt.subplot(2,3,6)
# Out:
# <AxesSubplot:>

# %%
## KDE plot
plt.figure(figsize=(8,5))
sns.kdeplot(data=df, x="F8")
plt.show()

# %%
plt.figure(figsize=(15,5))

plt.subplot(1,2,1)
sns.rugplot(data=df, x="F8")

plt.subplot(1,2,2)
sns.kdeplot(data=df, x="F8")
sns.rugplot(data=df, x="F8")
plt.show()

# %% [markdown]
# ## catplot:
# - catplot shows frequencies (or optionally fractions or precents) of the categories of one,two or three categorical variables.

# %%
df['F4']
# Out:
# 0       1.034985
# 1      -1.582681
# 2      -0.816802
# 3      -3.182493
# 4      -0.042551
#           ...
# 9995   -0.914846
# 9996    1.807518
# 9997   -0.266705
# 9998   -1.074000
# 9999    1.332360
# Name: F4, Length: 10000, dtype: float64

# %%
sns.catplot(x="F3",data=df, kind='count')
plt.title("Cat plot")
plt.xlabel('Category')
plt.show()

# %%
cat=["High","Medium","Low"]
sns.catplot(x='F4',y='F10',data=df, kind= 'bar', order='cat')
plt.title("cat plot")
plt.show()

# %% [markdown]
# ## bar plot:
# - it shows the relationship bewtween a numeric and a categoric variable.
# - Each entity of the categoric variable is represented as a bar.
# - the size of the bar represents the numeric value.

# %%
df['F1']
# Out:
# 0        True
# 1        True
# 2       False
# 3       False
# 4        True
#         ...
# 9995    False
# 9996     True
# 9997    False
# 9998    False
# 9999    False
# Name: F1, Length: 10000, dtype: bool

# %%
df.F1.value_counts().plot(kind='barh',color='Brown')    ## BArh = horizontal
plt.title("Bar plot")
plt.show()

# %%
df.F1.value_counts().plot(kind='bar',color='Brown')   ## bar = vartical
plt.title("Bar plot")
plt.show()

# %%
df.groupby('F4').max().plot(kind='bar')
plt.title("bar plot")
plt.show()

# %%
df.groupby('F4').max()
# Out:
#           F1         F2 F3        F5        F6        F7        F8        F9  \
# F4
# High    True  11.613698  C  9.525639  6.788231  6.334995  4.074327  6.754931
# Low     True   4.024338  C  7.176354  6.258013  4.104729  4.000489  7.866976
# Medium  True   6.196854  C  6.950355  5.473551  4.866533  3.304967  6.097847
#
#              F10       F11       F12
# F4
# High    8.828066  6.683955  2.938884
# Low     8.743985  4.318139  7.768817
# Medium  9.789986  4.304665  4.517500

# %%
df.groupby('F4').min()
# Out:
#            F1        F2 F3        F5        F6        F7        F8        F9  \
# F4
# High    False -5.753606  A -5.403084 -6.885453 -6.111982 -4.570084 -7.235824
# Low     False -8.466880  A -7.549882 -5.135007 -6.814792 -4.642428 -3.978838
# Medium  False -6.473574  A -4.873037 -5.834728 -4.765713 -4.867757 -5.093469
#
#              F10       F11       F12
# F4
# High   -3.571711 -1.691553 -8.112118
# Low    -8.056453 -5.451866 -7.438295
# Medium -5.059056 -2.482098 -8.437199

# %%
df.F3.value_counts().plot(kind='barh',color='yellow')
plt.title("bar Plot")
plt.show()

# %% [markdown]
# ## countplot:
# - a count plot is kind of like a histogram or a bar graph for some categorical . it simple shows the numbers occurance of an item based on a certain type of a category.

# %%
sns.countplot(df['F3'])
plt.title('count Plot')
plt.show()

# %% [markdown]
# ### 23/02/2023

# %% [markdown]
# # violinplot:
# - violin plot are used when you want to observe the distribution of numeric data. and are especially useful when you want to make a comparison of sitributors between multiple group's density curve can be compared to see where groups are similer or different.

# %%
sns.violinplot(df['F7'])
plt.title("violin plot")
plt.show()

# %% [markdown]
# ## stripplot:
# - A strip plot is a single axis scatter plot that is used to visualise the distribution of many indivisual one dimentional values.

# %%
sns.stripplot(x='F1', y='F5',data=df)
plt.title("stripplot")
plt.show()        ### stripplot with jitter.

# %%
sns.stripplot(x='F1', y='F5',data=df, jitter=False)
plt.title("stripplot")
plt.show()        ### stripplot without jitter.

# %% [markdown]
# ## Swarmplot:
# - a swarm plot is a another way of plotting the distribution of a attribute of the joint distribution of A couple of attributes.

# %%
sns.swarmplot(x='F1', y='F6', data=df)
plt.title("Swarmplot")
plt.show()      ### no overlapping.

# %% [markdown]
# ## FacetGrid:
# - facetgrid object takes a dataframes as input and the names of the variable that will form the row,column or hue dimentions of the grid. should be categorical and the data at each level of the variable will be used for a facet along that axis.

# %%
## facet of histplot of a feature
f=sns.FacetGrid(df, col='F2')
f.map(plt.hist, "F5")
plt.show()

# %%
## facet of scatterplot of a features.
f=sns.FacetGrid(df, col='F2',hue='F4')
f.map(plt.scatter, "F5","F7")
plt.show()

# %% [markdown]
# ## Lmplot:
# - Seaborn's implot is a 2D scatterplot with an optional overlaid regression line.
# - This is useful for comparing numeric variables.

# %%
sns.lmplot(x='F6',y='F12',data=df,hue='F1',fit_reg=False)
plt.title("LM Plot")
plt.show()

# %% [markdown]
# ## Box plot:
# - it shoes distribution of data in the quartile range which ranges through maximum or minimum whiskers of boxplot.
# - Helps in identifying the range or vlaues of outliars.

# %%
df.F5.describe()
# Out:
# count    10000.000000
# mean        -0.034990
# std          2.191369
# min         -7.549882
# 25%         -1.549544
# 50%         -0.226316
# 75%          1.174665
# max          9.525639
# Name: F5, dtype: float64

# %%
sns.boxplot(df.F5)
plt.title("BoxPlot")
plt.show()

# %% [markdown]
# ## part C:
#
# ### IRIS dataset:

# %%
# loasding iris datasset:
from sklearn.datasets import load_iris
iris=load_iris()

# %%
# strore featuires matrix in x

X = iris.data
#store target vector in y
y=iris.target

# %%
# Names of features in iris dataset
print(iris.feature_names)
# Out:
# ['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)']

# %%
# names of target in iris dataset:
print(iris.target_names)
# Out:
# ['setosa' 'versicolor' 'virginica']

# %%
# size of feature matrix
print(iris.data.shape)
# Out:
# (150, 4)

# %%
#checking iris data type
type(iris)
# Out:
# sklearn.utils.Bunch

# %%
# coverting Array in dataframes for smooth analysis.

ir_x=pd.DataFrame(X, columns=['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)'])
ir_y=pd.DataFrame(y, columns=['Species'])
iris=pd.concat([ir_x,ir_y], axis=1)

# %%
iris.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    Species
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0

# %% [markdown]
# ## iris = pd.DataFrame(data= np.c_[iris['data'], iris['target']], columns= iris['feature_names'] + ['species'])
#
# ##### we can use also this.

# %%
sns.scatterplot(x='sepal length (cm)', y='sepal width (cm)', data=iris)
plt.title("scatter Plot")
plt.show()

# %%
sns.scatterplot(x='sepal length (cm)', y='sepal width (cm)', data=iris, hue='Species')
plt.title("scatter Plot")
plt.show()

# %%
sns.scatterplot(x='sepal length (cm)', y='Species', data=iris)
plt.title("scatter Plot")
plt.show()

# %% [markdown]
# ## Scatter 3D:

# %%
z = df.F6
x = df.F7
y = df.F9

# creting figure
fig=plt.figure(figsize= (10,7))
ax=plt.axes(projection="3d")

# creating plot
ax.scatter3D(x,y,z,color='Red')
plt.title("simple 3D scatter plot")

# show plot
plt.show()

# %%
z = iris['sepal length (cm)']
x = iris['sepal width (cm)']
y = iris['petal length (cm)']

fig=plt.figure(figsize= (10,7))
ax=plt.axes(projection="3d")

ax.set_zlabel("sepel length")
ax.set_xlabel("sepel width")
ax.set_ylabel("petal length")

ax.scatter3D(x,y,z,color='blue')
plt.show()

# %% [markdown]
# # Heatmap:
# - A heatmap is graphical representation of data that uses a system of color coding to represent different values.
# - Heatmaps are uised in various forms of analysis but are mopst commonly used to show user behaviour on specific features in dataset.

# %% [markdown]
# ### "correlation does not imply causations."

# %%
## finding corelation bwtweeen the features.
iris_corr=iris.corr()
iris_corr
# Out:
#                    sepal length (cm)  sepal width (cm)  petal length (cm)  \
# sepal length (cm)           1.000000         -0.117570           0.871754
# sepal width (cm)           -0.117570          1.000000          -0.428440
# petal length (cm)           0.871754         -0.428440           1.000000
# petal width (cm)            0.817941         -0.366126           0.962865
# Species                     0.782561         -0.426658           0.949035
#
#                    petal width (cm)   Species
# sepal length (cm)          0.817941  0.782561
# sepal width (cm)          -0.366126 -0.426658
# petal length (cm)          0.962865  0.949035
# petal width (cm)           1.000000  0.956547
# Species                    0.956547  1.000000

# %%
# correlation value= -1 to +1

# %%
# Heatmap:
sns.heatmap(iris_corr, annot=True,cmap='Dark2')
plt.title("Heatmap")
plt.show()
# 'Accent', 'Accent_r', 'Blues', 'Blues_r', 'BrBG', 'BrBG_r', 'BuGn', 'BuGn_r', 'BuPu', 'BuPu_r', 'CMRmap', 'CMRmap_r', 'Dark2', 'Dark2_r', 'GnBu', 'GnBu_r', 'Greens', 'Greens_r', 'Greys', 'Greys_r', 'OrRd', 'OrRd_r', 'Oranges', 'Oranges_r', 'PRGn', 'PRGn_r', 'Paired', 'Paired_r', 'Pastel1', 'Pastel1_r', 'Pastel2', 'Pastel2_r', 'PiYG', 'PiYG_r', 'PuBu', 'PuBuGn', 'PuBuGn_r', 'PuBu_r', 'PuOr', 'PuOr_r', 'PuRd', 'PuRd_r', 'Purples', 'Purples_r', 'RdBu', 'RdBu_r', 'RdGy', 'RdGy_r', 'RdPu', 'RdPu_r', 'RdYlBu', 'RdYlBu_r', 'RdYlGn', 'RdYlGn_r', 'Reds', 'Reds_r', 'Set1', 'Set1_r', 'Set2', 'Set2_r', 'Set3', 'Set3_r', 'Spectral', 'Spectral_r', 'Wistia', 'Wistia_r', 'YlGn', 'YlGnBu', 'YlGnBu_r', 'YlGn_r', 'YlOrBr', 'YlOrBr_r', 'YlOrRd', 'YlOrRd_r', 'afmhot', 'afmhot_r', 'autumn', 'autumn_r', 'binary', 'binary_r', 'bone', 'bone_r', 'brg', 'brg_r', 'bwr', 'bwr_r', 'cividis', 'cividis_r', 'cool', 'cool_r', 'coolwarm', 'coolwarm_r', 'copper', 'copper_r', 'crest', 'crest_r', 'cubehelix', 'cubehelix_r', 'flag', 'flag_r', 'flare', 'flare_r', 'gist_earth', 'gist_earth_r', 'gist_gray', 'gist_gray_r', 'gist_heat', 'gist_heat_r', 'gist_ncar', 'gist_ncar_r', 'gist_rainbow', 'gist_rainbow_r', 'gist_stern', 'gist_stern_r', 'gist_yarg', 'gist_yarg_r', 'gnuplot', 'gnuplot2', 'gnuplot2_r', 'gnuplot_r', 'gray', 'gray_r', 'hot', 'hot_r', 'hsv', 'hsv_r', 'icefire', 'icefire_r', 'inferno', 'inferno_r', 'jet', 'jet_r', 'magma', 'magma_r', 'mako', 'mako_r', 'nipy_spectral', 'nipy_spectral_r', 'ocean', 'ocean_r', 'pink', 'pink_r', 'plasma', 'plasma_r', 'prism', 'prism_r', 'rainbow', 'rainbow_r', 'rocket', 'rocket_r', 'seismic', 'seismic_r', 'spring', 'spring_r', 'summer', 'summer_r', 'tab10', 'tab10_r', 'tab20', 'tab20_r', 'tab20b', 'tab20b_r', 'tab20c', 'tab20c_r', 'terrain', 'terrain_r', 'turbo', 'turbo_r', 'twilight', 'twilight_r', 'twilight_shifted', 'twilight_shifted_r', 'viridis', 'viridis_r', 'vlag', 'vlag_r', 'winter', 'winter_r'

# %%
iris['sepal length (cm)']
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
#       ...
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: sepal length (cm), Length: 150, dtype: float64

# %% [markdown]
# # Boxplot
#
# -  A Boxplot is a s

# %%
#boxplot of one feature:
sns.boxplot(iris['sepal length (cm)'])
# Out:
# <AxesSubplot:xlabel='sepal length (cm)'>

# %%
# boxplot or two features consisting of 3 classes.

sns.boxplot(x='Species',y='sepal length (cm)',data=iris)
plt.title("boxplot of different species")
plt.show()

# %% [markdown]
# # kdeplot:
# - Kdeplot is a kernal distribution estimation plot which depicts the probabily denisty function off the continuous or non parametric data variables.

# %%
# drawing kde plot on one continuous plot.
sns.kdeplot(iris['sepal length (cm)'])
plt.title("Kdeplot")
plt.show()

# %% [markdown]
# References:
# - https://www.journaldev.com/37898/python-numpy-where
# - https://www.tutorialspoint.com/seaborn/seaborn_facet_grid.htm
# - https://towardsdatascience.com/mastering-catplot-in-seaborn-categorical-data-visualization-guide-abab7b2067af
# - https://www.geeksforgeeks.org/scatterplot-using-seaborn-in-python/
# - https://www.w3schools.com/python/matplotlib_scatter.asp
